# %% [markdown]
# <a href="https://colab.research.google.com/github/timothy2077/My-Rolyal-Suite-Chatbot/blob/main/PP_G_AWS%EB%A5%BC_%ED%99%9C%EC%9A%A9%ED%95%9C_Telegram_Chatbot_100824.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # A. AWS 람다 설정

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### AWS 람다에는 pip처럼 손쉽게 패키지를 설치할 수 있는 도구가 없기에 코드를 파일형식으로 직접 업로드하기

# %% [markdown]
# 1. 계층 생성
# 2. 람다 제한 시간 설정을 1분으로 변경

# %% [markdown]
# # B. AWS API 게이트웨이 설정

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### 1. ngrok 주소로 등록되어 있는 웹훅 해제

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### 2. AWS API 게이트웨이 주소로 재등록

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # C. AWS 로그 살펴보기

# %% [markdown]
# #### ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
